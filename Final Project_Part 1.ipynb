# %%
pip install pandas-bokeh
# Out:
# Requirement already satisfied: pandas-bokeh in c:\users\elnaz\anaconda3\lib\site-packages (0.5.5)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: bokeh>=2.0 in c:\users\elnaz\anaconda3\lib\site-packages (from pandas-bokeh) (2.4.1)
# Requirement already satisfied: pandas>=0.22.0 in c:\users\elnaz\anaconda3\lib\site-packages (from pandas-bokeh) (1.3.4)
#
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\elnaz\anaconda3\lib\site-packages (from bokeh>=2.0->pandas-bokeh) (4.4.0)
# Requirement already satisfied: packaging>=16.8 in c:\users\elnaz\anaconda3\lib\site-packages (from bokeh>=2.0->pandas-bokeh) (21.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\elnaz\anaconda3\lib\site-packages (from bokeh>=2.0->pandas-bokeh) (6.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\elnaz\anaconda3\lib\site-packages (from bokeh>=2.0->pandas-bokeh) (2.11.3)
# Requirement already satisfied: tornado>=5.1 in c:\users\elnaz\anaconda3\lib\site-packages (from bokeh>=2.0->pandas-bokeh) (6.1)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\elnaz\anaconda3\lib\site-packages (from bokeh>=2.0->pandas-bokeh) (1.20.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\elnaz\anaconda3\lib\site-packages (from bokeh>=2.0->pandas-bokeh) (8.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\elnaz\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=2.0->pandas-bokeh) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\elnaz\anaconda3\lib\site-packages (from packaging>=16.8->bokeh>=2.0->pandas-bokeh) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\elnaz\anaconda3\lib\site-packages (from pandas>=0.22.0->pandas-bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\elnaz\anaconda3\lib\site-packages (from pandas>=0.22.0->pandas-bokeh) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\elnaz\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.22.0->pandas-bokeh) (1.16.0)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pandas_bokeh
from bokeh.io import show, output_notebook
from bokeh.plotting import figure
pandas_bokeh.output_notebook()
pd.set_option('plotting.backend', 'pandas_bokeh')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
GDP_original = pd.read_csv("Countries GDP 1960-2020.csv")
gdp = GDP_original.copy()

# %%
#90 countries,all with values 
gdp
# Out:
#                       Country Name Country Code      Continent          1960  \
# 0                        Australia          AUS        Oceania  1.860679e+10
# 1                          Austria          AUT         Europe  6.592694e+09
# 2                          Burundi          BDI         Africa  1.960000e+08
# 3                          Belgium          BEL         Europe  1.165872e+10
# 4                            Benin          BEN         Africa  2.261956e+08
# ..                             ...          ...            ...           ...
# 84                   United States          USA  North America  5.430000e+11
# 85  St. Vincent and the Grenadines          VCT  North America  1.306656e+07
# 86                    South Africa          ZAF         Africa  7.575397e+09
# 87                          Zambia          ZMB         Africa  7.130000e+08
# 88                        Zimbabwe          ZWE         Africa  1.052990e+09
#
#             1961          1962          1963          1964          1965  \
# 0   1.968306e+10  1.992272e+10  2.153993e+10  2.380110e+10  2.597715e+10
# 1   7.311750e+09  7.756110e+09  8.374175e+09  9.169984e+09  9.994071e+09
# 2   2.030000e+08  2.135000e+08  2.327500e+08  2.607500e+08  1.589950e+08
# 3   1.240015e+10  1.326402e+10  1.426002e+10  1.596011e+10  1.737146e+10
# 4   2.356682e+08  2.364349e+08  2.539276e+08  2.698190e+08  2.899087e+08
# ..           ...           ...           ...           ...           ...
# 84  5.630000e+11  6.050000e+11  6.390000e+11  6.860000e+11  7.440000e+11
# 85  1.399988e+07  1.452488e+07  1.370822e+07  1.475821e+07  1.510821e+07
# 86  7.972997e+09  8.497997e+09  9.423396e+09  1.037400e+10  1.133440e+10
# 87  6.962857e+08  6.931429e+08  7.187143e+08  8.394286e+08  1.082857e+09
# 88  1.096647e+09  1.117602e+09  1.159512e+09  1.217138e+09  1.311436e+09
#
#             1966  ...          2011          2012          2013          2014  \
# 0   2.730989e+10  ...  1.400000e+12  1.550000e+12  1.580000e+12  1.470000e+12
# 1   1.088768e+10  ...  4.310000e+11  4.090000e+11  4.300000e+11  4.420000e+11
# 2   1.654446e+08  ...  2.235821e+09  2.333308e+09  2.451625e+09  2.705783e+09
# 3   1.865188e+10  ...  5.230000e+11  4.960000e+11  5.220000e+11  5.350000e+11
# 4   3.029253e+08  ...  1.069332e+10  1.114136e+10  1.251785e+10  1.328453e+10
# ..           ...  ...           ...           ...           ...           ...
# 84  8.150000e+11  ...  1.550000e+13  1.620000e+13  1.680000e+13  1.750000e+13
# 85  1.609987e+07  ...  6.761296e+08  6.929333e+08  7.212074e+08  7.277148e+08
# 86  1.235500e+10  ...  4.580000e+11  4.340000e+11  4.010000e+11  3.810000e+11
# 87  1.264286e+09  ...  2.345952e+10  2.550306e+10  2.803724e+10  2.714102e+10
# 88  1.281750e+09  ...  1.410192e+10  1.711485e+10  1.909102e+10  1.949552e+10
#
#             2015          2016          2017          2018          2019  \
# 0   1.350000e+12  1.210000e+12  1.330000e+12  1.430000e+12  1.390000e+12
# 1   3.820000e+11  3.960000e+11  4.160000e+11  4.550000e+11  4.450000e+11
# 2   3.104395e+09  2.732809e+09  2.748180e+09  2.668496e+09  2.631434e+09
# 3   4.620000e+11  4.760000e+11  5.020000e+11  5.430000e+11  5.350000e+11
# 4   1.138816e+10  1.182107e+10  1.270165e+10  1.426241e+10  1.439169e+10
# ..           ...           ...           ...           ...           ...
# 84  1.820000e+13  1.870000e+13  1.950000e+13  2.060000e+13  2.140000e+13
# 85  7.554000e+08  7.744296e+08  7.921778e+08  8.113000e+08  8.250407e+08
# 86  3.470000e+11  3.240000e+11  3.810000e+11  4.050000e+11  3.880000e+11
# 87  2.125122e+10  2.095841e+10  2.587360e+10  2.631159e+10  2.330867e+10
# 88  1.996312e+10  2.054868e+10  1.758489e+10  1.811554e+10  1.928429e+10
#
#             2020
# 0   1.330000e+12
# 1   4.330000e+11
# 2   2.841786e+09
# 3   5.220000e+11
# 4   1.565155e+10
# ..           ...
# 84  2.100000e+13
# 85  8.074741e+08
# 86  3.350000e+11
# 87  1.811063e+10
# 88  1.805117e+10
#
# [89 rows x 64 columns]
