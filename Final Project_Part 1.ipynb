# %%
pip install pandas-bokeh
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pandas_bokeh
from bokeh.io import show, output_notebook
from bokeh.plotting import figure
pandas_bokeh.output_notebook()
pd.set_option('plotting.backend', 'pandas_bokeh')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
GDP_original = pd.read_csv("Countries GDP 1960-2020.csv")
gdp = GDP_original.copy()

# %%
#90 countries,all with values 
gdp
# Out:
#                       Country Name Country Code      Continent          1960  \
# 0                        Australia          AUS        Oceania  1.860679e+10
# 1                          Austria          AUT         Europe  6.592694e+09
# 2                          Burundi          BDI         Africa  1.960000e+08
# 3                          Belgium          BEL         Europe  1.165872e+10
# 4                            Benin          BEN         Africa  2.261956e+08
# ..                             ...          ...            ...           ...
# 84                   United States          USA  North America  5.430000e+11
# 85  St. Vincent and the Grenadines          VCT  North America  1.306656e+07
# 86                    South Africa          ZAF         Africa  7.575397e+09
# 87                          Zambia          ZMB         Africa  7.130000e+08
# 88                        Zimbabwe          ZWE         Africa  1.052990e+09
#
# ...

# %% [markdown]
# # Top 10 countries by GDP in 2020 world

# %%
Top_10_countries_2020 = display(gdp[['Country Name', 'Country Code', '2020']].sort_values('2020', ascending=False).head(10))
Top_10_countries_2020
# Out:
#       Country Name Country Code          2020
# 84   United States          USA  2.100000e+13
# 15           China          CHN  1.470000e+13
# 43           Japan          JPN  5.060000e+12
# 30  United Kingdom          GBR  2.760000e+12
# 38           India          IND  2.660000e+12
# 28          France          FRA  2.630000e+12
# 41           Italy          ITA  1.890000e+12
# 13          Canada          CAN  1.650000e+12
# 46     Korea, Rep.          KOR  1.640000e+12
# 0        Australia          AUS  1.330000e+12

# %%
Top_10_2020_World = gdp[gdp['Country Name'].isin([
     'United States',
     'China','Japan',
     'United Kingdom',
     'India','France','Italy','Canada',
     'Korea, Rep','Australia'
    ])].fillna(0)



Top_10_2020_World.plot_bokeh.pie(
    x="Country Name",
    y="2020",
    title="Top 10 Countries by GDP in 2020",
    )
# Out:
# __x__values_original
#   <div class="bk-root" id="eed26323-9ef7-4055-8256-45c5070f3d29" data-root-id="1038"></div>
# Figure(id='1038', ...)

# %% [markdown]
# # Top 10 countries by GDP in 2010 world

# %%
Top_10_countries_2010 = display(gdp[['Country Name', 'Country Code', '2010']].sort_values('2010', ascending=False).head(10))
Top_10_countries_2010
# Out:
#       Country Name Country Code          2010
# 84   United States          USA  1.500000e+13
# 15           China          CHN  6.090000e+12
# 43           Japan          JPN  5.760000e+12
# 28          France          FRA  2.640000e+12
# 30  United Kingdom          GBR  2.490000e+12
# 41           Italy          ITA  2.130000e+12
# 38           India          IND  1.680000e+12
# 13          Canada          CAN  1.620000e+12
# 25           Spain          ESP  1.420000e+12
# 0        Australia          AUS  1.150000e+12

# %%
Top_10_2010_World = gdp[gdp['Country Name'].isin([
     'United States',
     'China','Japan',
     'United Kingdom',
     'India','France','Italy','Canada',
     'Spain','Australia'
    ])].fillna(0)
Top_10_2010_World.plot_bokeh.pie(
    x="Country Name",
    y="2010",
    title="Top 10 Countries by GDP in 2010",
    name= "2010"
    )
# Out:
# __x__values_original
#   <div class="bk-root" id="defc00a8-a72d-4d1a-9ac8-a35e94bc8637" data-root-id="1188"></div>
# Figure(id='1188', ...)

# %% [markdown]
# # Top 3 Countries by Continent

# %% [markdown]
# # Asian

# %%
Top_3_Asian_countries_2020 = gdp[gdp["Continent"].isin(["Asia"])]
Top_3_Asian_countries_2020
# Out:
#             Country Name Country Code Continent          1960          1961  \
# 6             Bangladesh          BGD      Asia  4.274894e+09  4.817580e+09
# 15                 China          CHN      Asia  5.971647e+10  5.005687e+10
# 35  Hong Kong SAR, China          HKG      Asia  1.320797e+09  1.383682e+09
# 38                 India          IND      Asia  3.702988e+10  3.923244e+10
# 43                 Japan          JPN      Asia  4.430734e+10  5.350862e+10
# 46           Korea, Rep.          KOR      Asia  3.958191e+09  2.417558e+09
# 47             Sri Lanka          LKA      Asia  1.409874e+09  1.444328e+09
# 54              Malaysia          MYS      Asia  1.916242e+09  1.901869e+09
# 60                 Nepal          NPL      Asia  5.083344e+08  5.319596e+08
# 61              Pakistan          PAK      Asia  3.749265e+09  4.118648e+09
# 64           Philippines          PHL      Asia  7.515887e+09  8.171186e+09
# ...

# %%
Top_3_Asian_countries_2020 = display(Top_3_Asian_countries_2020[['Country Name', 'Country Code', '2020']].sort_values('2020', ascending=False).head(10))
# Out:
#             Country Name Country Code          2020
# 15                 China          CHN  1.470000e+13
# 43                 Japan          JPN  5.060000e+12
# 38                 India          IND  2.660000e+12
# 46           Korea, Rep.          KOR  1.640000e+12
# 81                Turkey          TUR  7.200000e+11
# 79              Thailand          THA  5.020000e+11
# 64           Philippines          PHL  3.610000e+11
# 35  Hong Kong SAR, China          HKG  3.470000e+11
# 71             Singapore          SGP  3.400000e+11
# 54              Malaysia          MYS  3.370000e+11

# %%
Asian = gdp[gdp['Country Name'].isin([
     'China',
     'Japan',
     'India'
    
    ])].fillna(0)
Asian.plot_bokeh.pie(
    x="Country Name",
    y="2020",
    title="Top 3 Asian Countries by GDP in 2020",
    )
# Out:
# __x__values_original
#   <div class="bk-root" id="8d20618b-83aa-453c-8be0-71980859335d" data-root-id="1347"></div>
# Figure(id='1347', ...)

# %% [markdown]
# # Europe

# %%
Top_3_Europe_countries_2020 = gdp[gdp["Continent"].isin(["Europe"])]
Top_3_Europe_countries_2020
# Out:
#       Country Name Country Code Continent          1960          1961  \
# 1          Austria          AUT    Europe  6.592694e+09  7.311750e+09
# 3          Belgium          BEL    Europe  1.165872e+10  1.240015e+10
# 25           Spain          ESP    Europe  1.207213e+10  1.383430e+10
# 26         Finland          FIN    Europe  5.224102e+09  5.921659e+09
# 28          France          FRA    Europe  6.222548e+10  6.746164e+10
# 30  United Kingdom          GBR    Europe  7.323397e+10  7.774197e+10
# 32          Greece          GRC    Europe  4.335186e+09  4.961400e+09
# 39         Ireland          IRL    Europe  1.939330e+09  2.088012e+09
# 40         Iceland          ISL    Europe  2.484341e+08  2.538857e+08
# 41           Italy          ITA    Europe  4.038529e+10  4.484276e+10
# 49      Luxembourg          LUX    Europe  7.039257e+08  7.041457e+08
# 58     Netherlands          NLD    Europe  1.227673e+10  1.349383e+10
# ...

# %%
Top_3_Europe_countries_2020 = display(Top_3_Europe_countries_2020[['Country Name', 'Country Code', '2020']].sort_values('2020', ascending=False).head(10))
# Out:
#       Country Name Country Code          2020
# 30  United Kingdom          GBR  2.760000e+12
# 28          France          FRA  2.630000e+12
# 41           Italy          ITA  1.890000e+12
# 25           Spain          ESP  1.280000e+12
# 58     Netherlands          NLD  9.140000e+11
# 74          Sweden          SWE  5.410000e+11
# 3          Belgium          BEL  5.220000e+11
# 1          Austria          AUT  4.330000e+11
# 39         Ireland          IRL  4.260000e+11
# 59          Norway          NOR  3.620000e+11

# %%
Europe = gdp[gdp['Country Name'].isin([
     'United Kingdom',
     'France',
     'Italy'
    ])].fillna(0)
Europe.plot_bokeh.pie(
    x="Country Name",
    y="2020",
    title="Top 3 Europe Countries by GDP in 2020",
    )
# Out:
# __x__values_original
#   <div class="bk-root" id="f1cbb099-5e43-4308-8a5a-43e72621c9dd" data-root-id="1515"></div>
# Figure(id='1515', ...)

# %% [markdown]
# # North America

# %%
Top_3_North_America_countries_2020 = gdp[gdp["Continent"].isin(["North America"])]
Top_3_North_America_countries_2020
# Out:
#                       Country Name Country Code      Continent          1960  \
# 7                     Bahamas, The          BHS  North America  1.698039e+08
# 8                           Belize          BLZ  North America  2.807189e+07
# 9                          Bermuda          BMU  North America  8.446665e+07
# 13                          Canada          CAN  North America  4.046172e+10
# 21                      Costa Rica          CRI  North America  5.075138e+08
# 22              Dominican Republic          DOM  North America  6.723997e+08
# 33                       Guatemala          GTM  North America  1.043600e+09
# 36                        Honduras          HND  North America  3.356500e+08
# 37                           Haiti          HTI  North America  2.731872e+08
# 42                         Jamaica          JAM  North America  6.990507e+08
# 45             St. Kitts and Nevis          KNA  North America  1.236656e+07
# ...

# %%
Top_3_North_America_countries_2020 = display(Top_3_North_America_countries_2020[['Country Name', 'Country Code', '2020']].sort_values('2020', ascending=False).head(10))
# Out:
#            Country Name Country Code          2020
# 84        United States          USA  2.100000e+13
# 13               Canada          CAN  1.650000e+12
# 52               Mexico          MEX  1.070000e+12
# 66          Puerto Rico          PRI  1.030000e+11
# 22   Dominican Republic          DOM  7.884470e+10
# 33            Guatemala          GTM  7.760463e+10
# 21           Costa Rica          CRI  6.184690e+10
# 62               Panama          PAN  5.397704e+10
# 36             Honduras          HND  2.366223e+10
# 80  Trinidad and Tobago          TTO  2.158804e+10

# %%
North_America = gdp[gdp['Country Name'].isin([
     'United States',
     'Canada',
     'Mexico'
    ])].fillna(0)
North_America.plot_bokeh.pie(
    x="Country Name",
    y="2020",
    title="Top 3 North_America Countries by GDP in 2020",
    )
# Out:
# __x__values_original
#   <div class="bk-root" id="2a5db02c-7425-4296-bd39-c17c36e4c804" data-root-id="1692"></div>
# Figure(id='1692', ...)

# %% [markdown]
# # South America

# %%
Top_3_South_America_countries_2020 = gdp[gdp["Continent"].isin(["South America"])]
Top_3_South_America_countries_2020
# Out:
#    Country Name Country Code      Continent          1960          1961  \
# 10      Bolivia          BOL  South America  3.738794e+08  4.066846e+08
# 14        Chile          CHL  South America  4.110000e+09  4.609727e+09
# 20     Colombia          COL  South America  4.031153e+09  4.540448e+09
# 24      Ecuador          ECU  South America  2.069465e+09  1.753850e+09
# 34       Guyana          GUY  South America  1.702152e+08  1.858485e+08
# 63         Peru          PER  South America  2.571908e+09  2.899655e+09
# 73     Suriname          SUR  South America  9.965000e+07  1.077000e+08
# 83      Uruguay          URY  South America  1.242289e+09  1.547389e+09
#
#             1962          1963          1964          1965          1966  ...  \
# 10  4.446652e+08  4.788060e+08  5.394915e+08  6.043771e+08  6.691919e+08  ...
# 14  5.416273e+09  5.668188e+09  5.982348e+09  6.026594e+09  7.072641e+09  ...
# 20  4.955544e+09  4.836167e+09  5.973367e+09  5.760762e+09  5.428519e+09  ...
# ...

# %%
Top_3_South_America_countries_2020 = display(Top_3_South_America_countries_2020[['Country Name', 'Country Code', '2020']].sort_values('2020', ascending=False).head(10))
# Out:
#    Country Name Country Code          2020
# 20     Colombia          COL  2.710000e+11
# 14        Chile          CHL  2.530000e+11
# 63         Peru          PER  2.020000e+11
# 24      Ecuador          ECU  9.880801e+10
# 83      Uruguay          URY  5.362883e+10
# 10      Bolivia          BOL  3.657276e+10
# 34       Guyana          GUY  5.471257e+09
# 73     Suriname          SUR  2.884248e+09

# %%
South_America = gdp[gdp['Country Name'].isin([
     'Colombia',
    'Chile',
    'Peru'
    ])].fillna(0)
South_America.plot_bokeh.pie(
    x="Country Name",
    y="2020",
    title="Top 3 South_America Countries by GDP in 2020",
    )
# Out:
# __x__values_original
#   <div class="bk-root" id="01fd394c-5715-4241-8870-8d33f256c437" data-root-id="1878"></div>
# Figure(id='1878', ...)

# %% [markdown]
# # Africa

# %%
Top_3_Africa_countries_2020 = gdp[gdp["Continent"].isin(["Africa"])]
Top_3_Africa_countries_2020
# Out:
#                 Country Name Country Code Continent          1960  \
# 2                    Burundi          BDI    Africa  1.960000e+08
# 4                      Benin          BEN    Africa  2.261956e+08
# 5               Burkina Faso          BFA    Africa  3.304428e+08
# 11                  Botswana          BWA    Africa  3.041231e+07
# 12  Central African Republic          CAF    Africa  1.121556e+08
# 16             Cote d'Ivoire          CIV    Africa  5.462036e+08
# 17                  Cameroon          CMR    Africa  6.142061e+08
# 18          Congo, Dem. Rep.          COD    Africa  3.359404e+09
# 19               Congo, Rep.          COG    Africa  1.317319e+08
# 23                   Algeria          DZA    Africa  2.723593e+09
# 29                     Gabon          GAB    Africa  1.414690e+08
# 31                     Ghana          GHA    Africa  1.217230e+09
# 44                     Kenya          KEN    Africa  7.912655e+08
# ...

# %%
Top_3_Africa_countries_2020 = display(Top_3_Africa_countries_2020[['Country Name', 'Country Code', '2020']].sort_values('2020', ascending=False).head(10))
# Out:
#         Country Name Country Code          2020
# 56           Nigeria          NGA  4.320000e+11
# 86      South Africa          ZAF  3.350000e+11
# 23           Algeria          DZA  1.450000e+11
# 50           Morocco          MAR  1.150000e+11
# 44             Kenya          KEN  1.010000e+11
# 31             Ghana          GHA  6.853228e+10
# 16     Cote d'Ivoire          CIV  6.134858e+10
# 18  Congo, Dem. Rep.          COD  4.871696e+10
# 17          Cameroon          CMR  4.080445e+10
# 82            Uganda          UGA  3.760037e+10

# %%
Africa = gdp[gdp['Country Name'].isin([
     'Nigeria',
     'South Africa',
     'Algeria'
    ])].fillna(0)
Africa.plot_bokeh.pie(
    x="Country Name",
    y="2020",
    title="Top 3 Africa Countries by GDP in 2020",
    )
# Out:
# __x__values_original
#   <div class="bk-root" id="1471cc49-5277-4627-852f-eb9bddc921da" data-root-id="2073"></div>
# Figure(id='2073', ...)

# %% [markdown]
# # Change oriantion of the table

# %%
gdp1 = GDP_original.copy()
GDP_covid = pd.read_csv("gdp_world_covid_2020_new.csv")
gdp_covid_copy = GDP_covid.copy()

# %%
gdp1
# Out:
#                       Country Name Country Code      Continent          1960  \
# 0                        Australia          AUS        Oceania  1.860679e+10
# 1                          Austria          AUT         Europe  6.592694e+09
# 2                          Burundi          BDI         Africa  1.960000e+08
# 3                          Belgium          BEL         Europe  1.165872e+10
# 4                            Benin          BEN         Africa  2.261956e+08
# ..                             ...          ...            ...           ...
# 84                   United States          USA  North America  5.430000e+11
# 85  St. Vincent and the Grenadines          VCT  North America  1.306656e+07
# 86                    South Africa          ZAF         Africa  7.575397e+09
# 87                          Zambia          ZMB         Africa  7.130000e+08
# 88                        Zimbabwe          ZWE         Africa  1.052990e+09
#
# ...

# %%
simple_gdp = gdp1.drop('Continent', inplace=True, axis=1)
print(simple_gdp)
# Out:
# None

# %%
simple_gdp = gdp1.drop('Country Code', inplace=True, axis=1)
display(simple_gdp)
# Out:
# None

# %%
gdp1
# Out:
#                       Country Name          1960          1961          1962  \
# 0                        Australia  1.860679e+10  1.968306e+10  1.992272e+10
# 1                          Austria  6.592694e+09  7.311750e+09  7.756110e+09
# 2                          Burundi  1.960000e+08  2.030000e+08  2.135000e+08
# 3                          Belgium  1.165872e+10  1.240015e+10  1.326402e+10
# 4                            Benin  2.261956e+08  2.356682e+08  2.364349e+08
# ..                             ...           ...           ...           ...
# 84                   United States  5.430000e+11  5.630000e+11  6.050000e+11
# 85  St. Vincent and the Grenadines  1.306656e+07  1.399988e+07  1.452488e+07
# 86                    South Africa  7.575397e+09  7.972997e+09  8.497997e+09
# 87                          Zambia  7.130000e+08  6.962857e+08  6.931429e+08
# 88                        Zimbabwe  1.052990e+09  1.096647e+09  1.117602e+09
#
# ...

# %%
melted_gdp1 = pd.melt(gdp1, id_vars=["Country Name"], var_name="Year", value_name="GDP")
display(melted_gdp1.head())

pivoted_gdp1 = melted_gdp1.pivot(index='Year', columns='Country Name', values='GDP')
display(pivoted_gdp1.head())
# Out:
#   Country Name  Year           GDP
# 0    Australia  1960  1.860679e+10
# 1      Austria  1960  6.592694e+09
# 2      Burundi  1960  1.960000e+08
# 3      Belgium  1960  1.165872e+10
# 4        Benin  1960  2.261956e+08
# Country Name       Algeria     Australia       Austria  Bahamas, The  \
# Year
# 1960          2.723593e+09  1.860679e+10  6.592694e+09   169803921.6
# 1961          2.434727e+09  1.968306e+10  7.311750e+09   190098039.2
# 1962          2.001428e+09  1.992272e+10  7.756110e+09   212254902.0
# 1963          2.702960e+09  2.153993e+10  8.374175e+09   237745098.0
# 1964          2.909293e+09  2.380110e+10  9.169984e+09   266666666.7
#
# Country Name    Bangladesh       Belgium       Belize        Benin  \
# Year
# 1960          4.274894e+09  1.165872e+10  28071888.56  226195579.4
# 1961          4.817580e+09  1.240015e+10  29964370.71  235668222.4
# 1962          5.081413e+09  1.326402e+10  31856922.86  236434906.8
# ...

# %%
top_10_countries_new = pivoted_gdp1.loc['2019':].T.dropna().sort_values(by='2019', ascending=False).head(10).index.tolist()

# %%
top_10_countries_new
# Out:
# ['United States',
#  'China',
#  'Japan',
#  'United Kingdom',
#  'India',
#  'France',
#  'Italy',
#  'Canada',
#  'Korea, Rep.',
#  'Spain']

# %%
# display(pivoted_gdp1['Year'])
pivoted_gdp1 = pivoted_gdp1.reset_index()

pivoted_gdp1['Year'] = pd.to_datetime(pivoted_gdp1['Year'])
pivoted_gdp1 = pivoted_gdp1.set_index('Year')
pivoted_gdp1.tail()
# Out:
# Country Name       Algeria     Australia       Austria  Bahamas, The  \
# Year
# 2016-01-01    1.600000e+11  1.210000e+12  3.960000e+11  1.199260e+10
# 2017-01-01    1.700000e+11  1.330000e+12  4.160000e+11  1.235970e+10
# 2018-01-01    1.750000e+11  1.430000e+12  4.550000e+11  1.283780e+10
# 2019-01-01    1.720000e+11  1.390000e+12  4.450000e+11  1.316440e+10
# 2020-01-01    1.450000e+11  1.330000e+12  4.330000e+11  9.907500e+09
#
# Country Name    Bangladesh       Belgium        Belize         Benin  \
# Year
# 2016-01-01    2.210000e+11  4.760000e+11  1.789304e+09  1.182107e+10
# 2017-01-01    2.500000e+11  5.020000e+11  1.858530e+09  1.270165e+10
# 2018-01-01    2.740000e+11  5.430000e+11  1.915900e+09  1.426241e+10
# 2019-01-01    3.030000e+11  5.350000e+11  1.982519e+09  1.439169e+10
# 2020-01-01    3.230000e+11  5.220000e+11  1.636281e+09  1.565155e+10
#
# Country Name       Bermuda       Bolivia  ...      Thailand          Togo  \
# ...

# %%
temp = pivoted_gdp1[top_10_countries_new].reset_index().fillna('')
temp.plot_bokeh.area(
    x="Year",
    stacked=True,
    legend="top_left",
    #colormap=["brown", "orange", "black", "grey", "blue", "green"],
    title="GDP Growth of the top 10 Countries",
    ylabel="USD",
    ylim=(0, 6e+13))
# Out:
#   <div class="bk-root" id="28bd21b2-fba1-4dbd-924e-00d620f4d350" data-root-id="2242"></div>
# Figure(id='2242', ...)

# %%
gdp_covid_copy['GDP_COVID'] = gdp_covid_copy['Last'] * 1000000000
gdp_covid_copy
# Out:
#       Country Name      Last  Previous Reference         Unit     GDP_COVID
# 0          Algeria    145.00    171.00    20-Dec  USD Billion  1.450000e+11
# 1        Australia   1331.00   1397.00    20-Dec  USD Billion  1.331000e+12
# 2          Austria    431.00    445.00    20-Dec  USD Billion  4.310000e+11
# 3     Bahamas, The     11.25     13.58    20-Dec  USD Billion  1.125000e+10
# 4       Bangladesh    324.00    303.00    20-Dec  USD Billion  3.240000e+11
# ..             ...       ...       ...       ...          ...           ...
# 84  United Kingdom   2708.00   2831.00    20-Dec  USD Billion  2.708000e+12
# 85   United States  20937.00  21433.00    20-Dec  USD Billion  2.093700e+13
# 86         Uruguay     53.63     61.23    20-Dec  USD Billion  5.363000e+10
# 87          Zambia     19.32     23.31    20-Dec  USD Billion  1.932000e+10
# 88        Zimbabwe     16.77     16.93    20-Dec  USD Billion  1.677000e+10
#
# [89 rows x 6 columns]

# %%
Final_lst_gdp_covid_copy = gdp_covid_copy.drop(['Last', 'Previous','Reference','Unit'], axis = 1)
Final_lst_gdp_covid_copy
# Out:
#       Country Name     GDP_COVID
# 0          Algeria  1.450000e+11
# 1        Australia  1.331000e+12
# 2          Austria  4.310000e+11
# 3     Bahamas, The  1.125000e+10
# 4       Bangladesh  3.240000e+11
# ..             ...           ...
# 84  United Kingdom  2.708000e+12
# 85   United States  2.093700e+13
# 86         Uruguay  5.363000e+10
# 87          Zambia  1.932000e+10
# 88        Zimbabwe  1.677000e+10
#
# [89 rows x 2 columns]

# %% [markdown]
# # Merge gdp & Covid

# %%
mrg_gdp_covid = pd.merge(gdp, Final_lst_gdp_covid_copy[["Country Name","GDP_COVID"]],on="Country Name",how="left")
mrg_gdp_covid
# Out:
#                       Country Name Country Code      Continent          1960  \
# 0                        Australia          AUS        Oceania  1.860679e+10
# 1                          Austria          AUT         Europe  6.592694e+09
# 2                          Burundi          BDI         Africa  1.960000e+08
# 3                          Belgium          BEL         Europe  1.165872e+10
# 4                            Benin          BEN         Africa  2.261956e+08
# ..                             ...          ...            ...           ...
# 84                   United States          USA  North America  5.430000e+11
# 85  St. Vincent and the Grenadines          VCT  North America  1.306656e+07
# 86                    South Africa          ZAF         Africa  7.575397e+09
# 87                          Zambia          ZMB         Africa  7.130000e+08
# 88                        Zimbabwe          ZWE         Africa  1.052990e+09
#
# ...

# %%
Top_10_countries_GDP_COVID = display(mrg_gdp_covid[['Country Name', 'Country Code', 'GDP_COVID']].sort_values('GDP_COVID', ascending=False).head(10))
Top_10_countries_GDP_COVID
# Out:
#       Country Name Country Code     GDP_COVID
# 84   United States          USA  2.093700e+13
# 15           China          CHN  1.472300e+13
# 43           Japan          JPN  4.975000e+12
# 30  United Kingdom          GBR  2.708000e+12
# 28          France          FRA  2.630000e+12
# 38           India          IND  2.623000e+12
# 41           Italy          ITA  1.886000e+12
# 13          Canada          CAN  1.644000e+12
# 46     Korea, Rep.          KOR  1.631000e+12
# 0        Australia          AUS  1.331000e+12

# %%
Top_3_gdp_covid = mrg_gdp_covid[mrg_gdp_covid['Country Name'].isin([
     'United States',
     'India',
     'Japan',
     'United Kingdom','France','India','Italy','Canada','Korea, Rep.','Australia'
    ])].fillna(0)
Top_3_gdp_covid.plot_bokeh.pie(
    x="Country Name",
    y="GDP_COVID",
    title="Top 10 Countries by GDP during Covid",
    )
# Out:
# __x__values_original
#   <div class="bk-root" id="cccc5b5b-0ff2-461d-bb53-af6a0d74cb12" data-root-id="3066"></div>
# Figure(id='3066', ...)

# %%
gdp_2 = mrg_gdp_covid.copy()

# %%
gdp_2.rename(columns = {'GDP_COVID':'2021'}, inplace = True)
gdp_2.tail()
# Out:
#                       Country Name Country Code      Continent          1960  \
# 84                   United States          USA  North America  5.430000e+11
# 85  St. Vincent and the Grenadines          VCT  North America  1.306656e+07
# 86                    South Africa          ZAF         Africa  7.575397e+09
# 87                          Zambia          ZMB         Africa  7.130000e+08
# 88                        Zimbabwe          ZWE         Africa  1.052990e+09
#
#             1961          1962          1963          1964          1965  \
# 84  5.630000e+11  6.050000e+11  6.390000e+11  6.860000e+11  7.440000e+11
# 85  1.399988e+07  1.452488e+07  1.370822e+07  1.475821e+07  1.510821e+07
# 86  7.972997e+09  8.497997e+09  9.423396e+09  1.037400e+10  1.133440e+10
# 87  6.962857e+08  6.931429e+08  7.187143e+08  8.394286e+08  1.082857e+09
# 88  1.096647e+09  1.117602e+09  1.159512e+09  1.217138e+09  1.311436e+09
#
# ...

# %%
simple_gdp_2 = gdp_2.drop('Continent', inplace=True, axis=1)
print(simple_gdp_2)
# Out:
# None

# %%
simple_gdp_2 = gdp_2.drop('Country Code', inplace=True, axis=1)
print(simple_gdp_2)
# Out:
# None

# %%
melted_gdp2 = pd.melt(gdp_2, id_vars=["Country Name"], var_name="Year", value_name="GDP")
display(melted_gdp2.head())

pivoted_gdp2 = melted_gdp2.pivot(index='Year', columns='Country Name', values='GDP')
display(pivoted_gdp2.tail())
Table_subplt = melted_gdp2.copy()
# Out:
#   Country Name  Year           GDP
# 0    Australia  1960  1.860679e+10
# 1      Austria  1960  6.592694e+09
# 2      Burundi  1960  1.960000e+08
# 3      Belgium  1960  1.165872e+10
# 4        Benin  1960  2.261956e+08
# Country Name       Algeria     Australia       Austria  Bahamas, The  \
# Year
# 2017          1.700000e+11  1.330000e+12  4.160000e+11  1.235970e+10
# 2018          1.750000e+11  1.430000e+12  4.550000e+11  1.283780e+10
# 2019          1.720000e+11  1.390000e+12  4.450000e+11  1.316440e+10
# 2020          1.450000e+11  1.330000e+12  4.330000e+11  9.907500e+09
# 2021          1.450000e+11  1.331000e+12  4.310000e+11  1.125000e+10
#
# Country Name    Bangladesh       Belgium        Belize         Benin  \
# Year
# 2017          2.500000e+11  5.020000e+11  1.858530e+09  1.270165e+10
# 2018          2.740000e+11  5.430000e+11  1.915900e+09  1.426241e+10
# 2019          3.030000e+11  5.350000e+11  1.982519e+09  1.439169e+10
# ...

# %% [markdown]
# # GDP of the top 10 Countries after Covid

# %%
top_10_countries_new2 = pivoted_gdp2.loc['2021':].T.dropna().sort_values(by='2021', ascending=False).head(10).index.tolist()
top_10_countries_new2
# Out:
# ['United States',
#  'China',
#  'Japan',
#  'United Kingdom',
#  'France',
#  'India',
#  'Italy',
#  'Canada',
#  'Korea, Rep.',
#  'Australia']

# %%
pivoted_gdp2 = pivoted_gdp2.reset_index()
pivoted_gdp2['Year'] = pd.to_datetime(pivoted_gdp2['Year'])
pivoted_gdp2 = pivoted_gdp2.set_index('Year')
pivoted_gdp2.tail()
# Out:
# Country Name       Algeria     Australia       Austria  Bahamas, The  \
# Year
# 2017-01-01    1.700000e+11  1.330000e+12  4.160000e+11  1.235970e+10
# 2018-01-01    1.750000e+11  1.430000e+12  4.550000e+11  1.283780e+10
# 2019-01-01    1.720000e+11  1.390000e+12  4.450000e+11  1.316440e+10
# 2020-01-01    1.450000e+11  1.330000e+12  4.330000e+11  9.907500e+09
# 2021-01-01    1.450000e+11  1.331000e+12  4.310000e+11  1.125000e+10
#
# Country Name    Bangladesh       Belgium        Belize         Benin  \
# Year
# 2017-01-01    2.500000e+11  5.020000e+11  1.858530e+09  1.270165e+10
# 2018-01-01    2.740000e+11  5.430000e+11  1.915900e+09  1.426241e+10
# 2019-01-01    3.030000e+11  5.350000e+11  1.982519e+09  1.439169e+10
# 2020-01-01    3.230000e+11  5.220000e+11  1.636281e+09  1.565155e+10
# 2021-01-01    3.240000e+11  5.150000e+11  1.760000e+09  1.565000e+10
#
# Country Name       Bermuda       Bolivia  ...      Thailand          Togo  \
# ...

# %%
temp2 = pivoted_gdp2[top_10_countries_new2].reset_index().fillna('')
temp2.plot_bokeh.area(
    x="Year",
    stacked=True,
    legend="top_left",
    #colormap=["brown", "orange", "black", "grey", "blue", "green"],
    title="GDP of the top 10 Countries after Covid",
    ylabel="USD",
    ylim=(0, 6e+13))
# Out:
#   <div class="bk-root" id="fc02593d-6d41-4098-971f-d27466b41b60" data-root-id="3285"></div>
# Figure(id='3285', ...)

# %% [markdown]
# # GDP of all Countries in separate graph

# %%
mrg_gdp_covid_3 = pd.merge(gdp, Final_lst_gdp_covid_copy[["Country Name","GDP_COVID"]],on="Country Name",how="left")
mrg_gdp_covid_3
# Out:
#                       Country Name Country Code      Continent          1960  \
# 0                        Australia          AUS        Oceania  1.860679e+10
# 1                          Austria          AUT         Europe  6.592694e+09
# 2                          Burundi          BDI         Africa  1.960000e+08
# 3                          Belgium          BEL         Europe  1.165872e+10
# 4                            Benin          BEN         Africa  2.261956e+08
# ..                             ...          ...            ...           ...
# 84                   United States          USA  North America  5.430000e+11
# 85  St. Vincent and the Grenadines          VCT  North America  1.306656e+07
# 86                    South Africa          ZAF         Africa  7.575397e+09
# 87                          Zambia          ZMB         Africa  7.130000e+08
# 88                        Zimbabwe          ZWE         Africa  1.052990e+09
#
# ...

# %%
mrg_gdp_covid_3.rename(columns = {'GDP_COVID':'2021'}, inplace = True)

# %%
Table_subplt
# Out:
#                         Country Name  Year           GDP
# 0                          Australia  1960  1.860679e+10
# 1                            Austria  1960  6.592694e+09
# 2                            Burundi  1960  1.960000e+08
# 3                            Belgium  1960  1.165872e+10
# 4                              Benin  1960  2.261956e+08
# ...                              ...   ...           ...
# 5513                   United States  2021  2.093700e+13
# 5514  St. Vincent and the Grenadines  2021           NaN
# 5515                    South Africa  2021  3.020000e+11
# 5516                          Zambia  2021  1.932000e+10
# 5517                        Zimbabwe  2021  1.677000e+10
#
# [5518 rows x 3 columns]

# %%
Table_subplt.groupby('Country Name').plot(x='Year', y='GDP')
# Out:
#   <div class="bk-root" id="2a53bd9b-b687-44e2-ae6a-66f51d5a87bc" data-root-id="4124"></div>
#   <div class="bk-root" id="d4fc5fe9-8f3c-41c3-b7d7-7abdd3a82dfe" data-root-id="4383"></div>
#   <div class="bk-root" id="ab72056d-df4b-49e9-b073-72c504e5330c" data-root-id="4650"></div>
#   <div class="bk-root" id="793f69b8-3af6-4f2f-877a-dca7ef9be838" data-root-id="4925"></div>
#   <div class="bk-root" id="1a721c3b-8efa-4047-a4f7-fa5d8008fdb0" data-root-id="5208"></div>
#   <div class="bk-root" id="21fc9a5b-d2d6-4852-a678-05048775f0fe" data-root-id="5499"></div>
#   <div class="bk-root" id="b8cfde56-d65c-4df2-ac8c-04b0b5ec840f" data-root-id="5798"></div>
#   <div class="bk-root" id="ec80a4c6-497f-4090-bf2b-c974188f391a" data-root-id="6105"></div>
#   <div class="bk-root" id="3eea7b92-4396-4ee5-afe5-e93e81780c33" data-root-id="6420"></div>
#   <div class="bk-root" id="53d8a017-2034-40bd-a23e-66f78657d423" data-root-id="6743"></div>
# ...

# %%
Table_mrg_gdp_covid = mrg_gdp_covid.copy()
Table_mrg_gdp_covid
# Out:
#                       Country Name Country Code      Continent          1960  \
# 0                        Australia          AUS        Oceania  1.860679e+10
# 1                          Austria          AUT         Europe  6.592694e+09
# 2                          Burundi          BDI         Africa  1.960000e+08
# 3                          Belgium          BEL         Europe  1.165872e+10
# 4                            Benin          BEN         Africa  2.261956e+08
# ..                             ...          ...            ...           ...
# 84                   United States          USA  North America  5.430000e+11
# 85  St. Vincent and the Grenadines          VCT  North America  1.306656e+07
# 86                    South Africa          ZAF         Africa  7.575397e+09
# 87                          Zambia          ZMB         Africa  7.130000e+08
# 88                        Zimbabwe          ZWE         Africa  1.052990e+09
#
# ...

# %%
a = gdp[gdp["Country Name"].isin(["Canada"])]
a
# Out:
#    Country Name Country Code      Continent          1960          1961  \
# 13       Canada          CAN  North America  4.046172e+10  4.093495e+10
#
#             1962          1963          1964          1965          1966  ...  \
# 13  4.222745e+10  4.502999e+10  4.937752e+10  5.451518e+10  6.108838e+10  ...
#
#             2011          2012          2013          2014          2015  \
# 13  1.790000e+12  1.830000e+12  1.850000e+12  1.810000e+12  1.560000e+12
#
#             2016          2017          2018          2019          2020
# 13  1.530000e+12  1.650000e+12  1.730000e+12  1.740000e+12  1.650000e+12
#
# [1 rows x 64 columns]

# %%
mlt = pd.melt(a, id_vars=["Country Name"], var_name="Year", value_name="GDP")
display(mlt.head())

pvt = mlt.pivot(index='Year', columns='Country Name', values='GDP')
display(pvt.tail())
# Out:
#   Country Name          Year            GDP
# 0       Canada  Country Code            CAN
# 1       Canada     Continent  North America
# 2       Canada          1960  40461721693.0
# 3       Canada          1961  40934952064.0
# 4       Canada          1962  42227447632.0
# Country Name           Canada
# Year
# 2018          1730000000000.0
# 2019          1740000000000.0
# 2020          1650000000000.0
# Continent       North America
# Country Code              CAN

# %%
pvt.drop(["Continent","Country Code"], axis=0, inplace=True)
pvt
# Out:
# Country Name           Canada
# Year
# 1960            40461721693.0
# 1961            40934952064.0
# 1962            42227447632.0
# 1963            45029988561.0
# 1964            49377522897.0
# ...                       ...
# 2016          1530000000000.0
# 2017          1650000000000.0
# 2018          1730000000000.0
# 2019          1740000000000.0
# 2020          1650000000000.0
#
# [61 rows x 1 columns]

# %%
pvt = pvt.reset_index()
pvt["Year"] = pd.to_datetime(pvt["Year"])
#pvt = pvt.set_index("Year")

pvt
# Out:
# Country Name  level_0  index       Year           Canada
# 0                   0      0 1960-01-01    40461721693.0
# 1                   1      1 1961-01-01    40934952064.0
# 2                   2      2 1962-01-01    42227447632.0
# 3                   3      3 1963-01-01    45029988561.0
# 4                   4      4 1964-01-01    49377522897.0
# ..                ...    ...        ...              ...
# 56                 56     56 2016-01-01  1530000000000.0
# 57                 57     57 2017-01-01  1650000000000.0
# 58                 58     58 2018-01-01  1730000000000.0
# 59                 59     59 2019-01-01  1740000000000.0
# 60                 60     60 2020-01-01  1650000000000.0
#
# [61 rows x 4 columns]

# %% [markdown]
# # Top 3 North America Countries GDP 1960-2020

# %%
Year = pvt["Year"]
Country = pvt["Canada"]

b = gdp[gdp["Country Name"].isin(["Mexico"])]
mlt1 = pd.melt(b, id_vars=["Country Name"], var_name="Year", value_name="GDP")
pvt1 = mlt1.pivot(index='Year', columns='Country Name', values='GDP')
pvt1.drop(["Continent","Country Code"], axis=0, inplace=True)
pvt1 = pvt1.reset_index()
pvt1["Year"] = pd.to_datetime(pvt1["Year"])
Year1 = pvt1["Year"]
Country1 = pvt1["Mexico"]

c = gdp[gdp["Country Name"].isin(["United States"])]
mlt2 = pd.melt(c, id_vars=["Country Name"], var_name="Year", value_name="GDP")
pvt2 = mlt2.pivot(index='Year', columns='Country Name', values='GDP')
pvt2.drop(["Continent","Country Code"], axis=0, inplace=True)
pvt2 = pvt2.reset_index()
pvt2["Year"] = pd.to_datetime(pvt2["Year"])
Year2 = pvt2["Year"]
Country2 = pvt2["United States"]



fig, ax = plt.subplots(figsize=(8, 6))

#plt.plot(Year, GDP)
plt.title('North America Continent GDP - 1960-2020 ')
plt.xlabel('Year', fontsize=15)
plt.ylabel('GDP-USD')

plt.plot(Year, Country, label='United States', c = 'g')
plt.plot(Year1, Country1, label='Canada', c = 'b')
plt.plot(Year2, Country2, label='Mexico', c = 'r')
plt.legend()

ax.plot(Year, Country)
ax.plot(Year1, Country1)
ax.plot(Year2, Country2)

# %% [markdown]
# # Top 3 Asia Countries GDP 1960-2020

# %%
a = gdp[gdp["Country Name"].isin(["China"])]
mlt = pd.melt(a, id_vars=["Country Name"], var_name="Year", value_name="GDP")
pvt = mlt.pivot(index='Year', columns='Country Name', values='GDP')
pvt.drop(["Continent","Country Code"], axis=0, inplace=True)
pvt = pvt.reset_index()
pvt["Year"] = pd.to_datetime(pvt["Year"])
Year = pvt["Year"]
Country = pvt["China"]

b = gdp[gdp["Country Name"].isin(["Japan"])]
mlt1 = pd.melt(b, id_vars=["Country Name"], var_name="Year", value_name="GDP")
pvt1 = mlt1.pivot(index='Year', columns='Country Name', values='GDP')
pvt1.drop(["Continent","Country Code"], axis=0, inplace=True)
pvt1 = pvt1.reset_index()
pvt1["Year"] = pd.to_datetime(pvt1["Year"])
Year1 = pvt1["Year"]
Country1 = pvt1["Japan"]

c = gdp[gdp["Country Name"].isin(["India"])]
mlt2 = pd.melt(c, id_vars=["Country Name"], var_name="Year", value_name="GDP")
pvt2 = mlt2.pivot(index='Year', columns='Country Name', values='GDP')
pvt2.drop(["Continent","Country Code"], axis=0, inplace=True)
pvt2 = pvt2.reset_index()
pvt2["Year"] = pd.to_datetime(pvt2["Year"])
Year2 = pvt2["Year"]
Country2 = pvt2["India"]



fig, ax = plt.subplots(figsize=(8, 6))


plt.title('Asia Countries GDP - 1960-2020 ')
plt.xlabel('Year', fontsize=15)
plt.ylabel('GDP-USD')

plt.plot(Year, Country, label='China', c = 'b')
plt.plot(Year1, Country1, label='Japan', c = 'r')
plt.plot(Year2, Country2, label='India', c = 'g')
plt.legend()

ax.plot(Year, Country)
ax.plot(Year1, Country1)
ax.plot(Year2, Country2)

# %% [markdown]
# # Top 3 Europe Countries GDP 1960-2020

# %%
a = gdp[gdp["Country Name"].isin(["France"])]
mlt = pd.melt(a, id_vars=["Country Name"], var_name="Year", value_name="GDP")
pvt = mlt.pivot(index='Year', columns='Country Name', values='GDP')
pvt.drop(["Continent","Country Code"], axis=0, inplace=True)
pvt = pvt.reset_index()
pvt["Year"] = pd.to_datetime(pvt["Year"])
Year = pvt["Year"]
Country = pvt["France"]

b = gdp[gdp["Country Name"].isin(["United Kingdom"])]
mlt1 = pd.melt(b, id_vars=["Country Name"], var_name="Year", value_name="GDP")
pvt1 = mlt1.pivot(index='Year', columns='Country Name', values='GDP')
pvt1.drop(["Continent","Country Code"], axis=0, inplace=True)
pvt1 = pvt1.reset_index()
pvt1["Year"] = pd.to_datetime(pvt1["Year"])
Year1 = pvt1["Year"]
Country1 = pvt1["United Kingdom"]

c = gdp[gdp["Country Name"].isin(["Italy"])]
mlt2 = pd.melt(c, id_vars=["Country Name"], var_name="Year", value_name="GDP")
pvt2 = mlt2.pivot(index='Year', columns='Country Name', values='GDP')
pvt2.drop(["Continent","Country Code"], axis=0, inplace=True)
pvt2 = pvt2.reset_index()
pvt2["Year"] = pd.to_datetime(pvt2["Year"])
Year2 = pvt2["Year"]
Country2 = pvt2["Italy"]



fig, ax = plt.subplots(figsize=(8, 6))
plt.title('Europe Countries GDP - 1960-2020 ')
plt.xlabel('Year', fontsize=15)
plt.ylabel('GDP-USD')

plt.plot(Year, Country, label='United Kingdom', c = 'r')
plt.plot(Year1, Country1, label='France', c = 'b')
plt.plot(Year2, Country2, label='Italy', c = 'g')
plt.legend()

ax.plot(Year, Country)
ax.plot(Year1, Country1)
ax.plot(Year2, Country2)

# %% [markdown]
# # Top 3 South America Countries GDP 1960-2020

# %%
a = gdp[gdp["Country Name"].isin(["Chile"])]
mlt = pd.melt(a, id_vars=["Country Name"], var_name="Year", value_name="GDP")
pvt = mlt.pivot(index='Year', columns='Country Name', values='GDP')
pvt.drop(["Continent","Country Code"], axis=0, inplace=True)
pvt = pvt.reset_index()
pvt["Year"] = pd.to_datetime(pvt["Year"])
Year = pvt["Year"]
Country = pvt["Chile"]

b = gdp[gdp["Country Name"].isin(["Colombia"])]
mlt1 = pd.melt(b, id_vars=["Country Name"], var_name="Year", value_name="GDP")
pvt1 = mlt1.pivot(index='Year', columns='Country Name', values='GDP')
pvt1.drop(["Continent","Country Code"], axis=0, inplace=True)
pvt1 = pvt1.reset_index()
pvt1["Year"] = pd.to_datetime(pvt1["Year"])
Year1 = pvt1["Year"]
Country1 = pvt1["Colombia"]

c = gdp[gdp["Country Name"].isin(["Peru"])]
mlt2 = pd.melt(c, id_vars=["Country Name"], var_name="Year", value_name="GDP")
pvt2 = mlt2.pivot(index='Year', columns='Country Name', values='GDP')
pvt2.drop(["Continent","Country Code"], axis=0, inplace=True)
pvt2 = pvt2.reset_index()
pvt2["Year"] = pd.to_datetime(pvt2["Year"])
Year2 = pvt2["Year"]
Country2 = pvt2["Peru"]



fig, ax = plt.subplots(figsize=(8, 6))
plt.title('South America Countries GDP - 1960-2020 ')
plt.xlabel('Year', fontsize=15)
plt.ylabel('GDP-USD')
    
plt.plot(Year, Country, label='Colombia', c = 'r')
plt.plot(Year1, Country1, label='Chile', c = 'b')
plt.plot(Year2, Country2, label='Peru', c = 'g')
plt.legend()

ax.plot(Year, Country)
ax.plot(Year1, Country1)
ax.plot(Year2, Country2)

# %% [markdown]
# # Top 3 Africa Countries GDP 1960-2020

# %%
a = gdp[gdp["Country Name"].isin(["South Africa"])]
mlt = pd.melt(a, id_vars=["Country Name"], var_name="Year", value_name="GDP")
pvt = mlt.pivot(index='Year', columns='Country Name', values='GDP')
pvt.drop(["Continent","Country Code"], axis=0, inplace=True)
pvt = pvt.reset_index()
pvt["Year"] = pd.to_datetime(pvt["Year"])
Year = pvt["Year"]
Country = pvt["South Africa"]

b = gdp[gdp["Country Name"].isin(["Nigeria"])]
mlt1 = pd.melt(b, id_vars=["Country Name"], var_name="Year", value_name="GDP")
pvt1 = mlt1.pivot(index='Year', columns='Country Name', values='GDP')
pvt1.drop(["Continent","Country Code"], axis=0, inplace=True)
pvt1 = pvt1.reset_index()
pvt1["Year"] = pd.to_datetime(pvt1["Year"])
Year1 = pvt1["Year"]
Country1 = pvt1["Nigeria"]

c = gdp[gdp["Country Name"].isin(["Algeria"])]
mlt2 = pd.melt(c, id_vars=["Country Name"], var_name="Year", value_name="GDP")
pvt2 = mlt2.pivot(index='Year', columns='Country Name', values='GDP')
pvt2.drop(["Continent","Country Code"], axis=0, inplace=True)
pvt2 = pvt2.reset_index()
pvt2["Year"] = pd.to_datetime(pvt2["Year"])
Year2 = pvt2["Year"]
Country2 = pvt2["Algeria"]

fig, ax = plt.subplots(figsize=(8, 6))
plt.title('Africa Countries GDP - 1960-2020 ')
plt.xlabel('Year', fontsize=15)
plt.ylabel('GDP-USD')
    
plt.plot(Year, Country, label='Nigeria', c = 'r')
plt.plot(Year1, Country1, label='South Africa', c = 'b')
plt.plot(Year2, Country2, label='Algeria', c = 'g')
plt.legend()

ax.plot(Year, Country)
ax.plot(Year1, Country1)
ax.plot(Year2, Country2)

# %%
GDP_Growth_copy = pd.read_csv("GDP-Growth_covid1.csv")
GDP_Growth = GDP_Growth_copy.copy()
GDP_Growth
# Out:
#       Country Name      Last  Previous Reference         Unit  \
# 0          Algeria    145.00    171.00    20-Dec  USD Billion
# 1        Australia   1331.00   1397.00    20-Dec  USD Billion
# 2          Austria    431.00    445.00    20-Dec  USD Billion
# 3     Bahamas, The     11.25     13.58    20-Dec  USD Billion
# 4       Bangladesh    324.00    303.00    20-Dec  USD Billion
# ..             ...       ...       ...       ...          ...
# 84  United Kingdom   2708.00   2831.00    20-Dec  USD Billion
# 85   United States  20937.00  21433.00    20-Dec  USD Billion
# 86         Uruguay     53.63     61.23    20-Dec  USD Billion
# 87          Zambia     19.32     23.31    20-Dec  USD Billion
# 88        Zimbabwe     16.77     16.93    20-Dec  USD Billion
#
#     GDP_growth_percentage GDP_growth_percentage.1
# 0                  -5.992             medium fall
# 1                  -2.438              short fall
# 2                  -6.590               high fall
# ...

# %% [markdown]
# # GDP Negative-Positive Growth Percentage

# %%
GDP_Growth = GDP_Growth.drop(columns=["Last","Previous","Unit"])

# %%
GDP_Growth.rename(columns = {'Reference':'Year','GDP_growth_percentage':'GDP_Growth_Percentage','GDP_growth_percentage.1':'GDP_Growth_State'}, inplace = True)
GDP_Growth
# Out:
#       Country Name    Year  GDP_Growth_Percentage GDP_Growth_State
# 0          Algeria  20-Dec                 -5.992      medium fall
# 1        Australia  20-Dec                 -2.438       short fall
# 2          Austria  20-Dec                 -6.590        high fall
# 3     Bahamas, The  20-Dec                -16.281   very high fall
# 4       Bangladesh  20-Dec                  3.798      medium rise
# ..             ...     ...                    ...              ...
# 84  United Kingdom  20-Dec                 -9.920        high fall
# 85   United States  20-Dec                 -3.505      medium fall
# 86         Uruguay  20-Dec                 -5.700      medium fall
# 87          Zambia  20-Dec                 -3.497      medium fall
# 88        Zimbabwe  20-Dec                 -8.002        high fall
#
# [89 rows x 4 columns]

# %%
GDP_Growth['GDP_Growth_Percentage'].dtypes
# Out:
# dtype('float64')

# %%
Negative_GDP_Growth = GDP_Growth[GDP_Growth["GDP_Growth_Percentage"] < 0]
Positive_GDP_Growth = GDP_Growth[GDP_Growth["GDP_Growth_Percentage"] > 0]

ax = Negative_GDP_Growth.plot.bar(x='Country Name', y='GDP_Growth_Percentage')
ax = Positive_GDP_Growth.plot.bar(x='Country Name', y='GDP_Growth_Percentage')
# Out:
#   <div class="bk-root" id="6c4f9474-a0ab-4478-8aa2-54d7c067094c" data-root-id="60561"></div>
#   <div class="bk-root" id="cb9cd0d1-fd8f-46d9-8043-e081b9866e7b" data-root-id="61584"></div>
